# %% [markdown]
# <a href="https://colab.research.google.com/github/AQuaMaRIne307/AQuaMaRIne307/blob/main/LeetCode/LabWork/Day-1/Find_Pivot_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pivot_index(nums):
    total_sum = sum(nums)
    left_sum = 0

    for i, num in enumerate(nums):
        right_sum = total_sum - left_sum - num
        if left_sum == right_sum:
            return i
        left_sum += num

    return -1

# Example usage
nums = [1, 7, 3, 6, 5, 6]
print(pivot_index(nums))  # Output: 3
# Out:
# 3
